# %% [markdown]
# ### import packages

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import lightgbm as lgb

pd.set_option('display.max_columns', None)

# %%
def data_process(prop):
    prop.rename(columns={
        'parcelid': 'parcelid',  # Unique identifier of parcels
        'airconditioningtypeid': 'cooling_id',  # type of cooling system (if any), 1~13
        'architecturalstyletypeid': 'architecture_style_id',  # Architectural style of the home, 1~27
        'basementsqft': 'basement_sqft',  # Size of the basement
        'bathroomcnt': 'bathroom_cnt',  # Number of bathrooms (including fractional bathrooms)
        'bedroomcnt': 'bedroom_cnt',  # Number of bedrooms
        'buildingclasstypeid': 'framing_id',  # The building framing type, 1~5
        'buildingqualitytypeid': 'quality_id',  # building condition from best (lowest) to worst (highest)
        'calculatedbathnbr': 'bathroom_cnt_calc',  # Same meaning as 'bathroom_cnt'?
        'decktypeid': 'deck_id',  # Type of deck (if any)
        'finishedfloor1squarefeet': 'floor1_sqft',  # Size of finished living area on first floor
        'calculatedfinishedsquarefeet': 'finished_area_sqft_calc',  # calculated total finished living area
        'finishedsquarefeet12': 'finished_area_sqft',  # Same meaning as 'finished_area_sqft_calc'?
        'finishedsquarefeet13': 'perimeter_area',  # Perimeter living area
        'finishedsquarefeet15': 'total_area',  # Total area
        'finishedsquarefeet50': 'floor1_sqft_unk',  # Same meaning as 'floor1_sqft'?
        'finishedsquarefeet6': 'base_total_area',  # Base unfinished and finished area
        'fips': 'fips',  # Federal Information Processing Standard code
        'fireplacecnt': 'fireplace_cnt',  # Number of fireplaces in the home (if any)
        'fullbathcnt': 'bathroom_full_cnt',  # Number of full bathrooms
        'garagecarcnt': 'garage_cnt',  # Total number of garages
        'garagetotalsqft': 'garage_sqft',  # Total size of the garages
        'hashottuborspa': 'spa_flag',  # Whether the home has a hot tub or spa
        'heatingorsystemtypeid': 'heating_id',  # type of heating system, 1~25
        'latitude': 'latitude',  # latitude of the middle of the parcel multiplied by 1e6
        'longitude': 'longitude',  # longitude of the middle of the parcel multiplied by 1e6
        'lotsizesquarefeet': 'lot_sqft',  # Area of the lot in sqft
        'poolcnt': 'pool_cnt', # Number of pools in the lot (if any)
        'poolsizesum': 'pool_total_size',  # Total size of the pools
        'pooltypeid10': 'pool_unk_1',
        'pooltypeid2': 'pool_unk_2',
        'pooltypeid7': 'pool_unk_3',
        'propertycountylandusecode': 'county_landuse_code',
        'propertylandusetypeid': 'landuse_type_id' ,  # Type of land use the property is zoned for, 25 categories
        'propertyzoningdesc': 'zoning_description',  # Allowed land uses (zoning) for that property
        'rawcensustractandblock': 'census_1',
        'regionidcity': 'city_id',  # City in which the property is located (if any)
        'regionidcounty': 'county_id',  # County in which the property is located
        'regionidneighborhood': 'neighborhood_id',  # Neighborhood in which the property is located
        'regionidzip': 'region_zip',
        'roomcnt': 'room_cnt',  # Total number of rooms in the principal residence
        'storytypeid': 'story_id',  # Type of floors in a multi-story house, 1~35
        'threequarterbathnbr': 'bathroom_small_cnt',  # Number of 3/4 bathrooms
        'typeconstructiontypeid': 'construction_id',  # Type of construction material, 1~18
        'unitcnt': 'unit_cnt',  # Number of units the structure is built into (2=duplex, 3=triplex, etc)
        'yardbuildingsqft17': 'patio_sqft',  # Patio in yard
        'yardbuildingsqft26': 'storage_sqft',  # Storage shed/building in yard
        'yearbuilt': 'year_built',  # The year the principal residence was built
        'numberofstories': 'story_cnt',  # Number of stories or levels the home has
        'fireplaceflag': 'fireplace_flag',  # Whether the home has a fireplace
        'structuretaxvaluedollarcnt': 'tax_structure',
        'taxvaluedollarcnt': 'tax_parcel',
        'assessmentyear': 'tax_year',  # The year of the property tax assessment (2015 for 2016 data)
        'landtaxvaluedollarcnt': 'tax_land',
        'taxamount': 'tax_property',
        'taxdelinquencyflag': 'tax_overdue_flag',  # Property taxes are past due as of 2015
        'taxdelinquencyyear': 'tax_overdue_year',  # Year for which the unpaid propert taxes were due
        'censustractandblock': 'census_2'
    }, inplace=True)   
    
    def convert_true_to_float(df, col):
        df.loc[df[col] == 'true', col] = '1'
        df.loc[df[col] == 'Y', col] = '1'
        df[col] = df[col].astype(float)
    
    for col in ['spa_flag','fireplace_flag','tax_overdue_flag']:
        convert_true_to_float(prop, col)
    
    return prop

# %%
# %%time
#properties of houses, need to predict each house logerror 
properties_2016_df = pd.read_csv('/glade/scratch/wmingch/ML_project/Zillow_prize/properties_2016.csv') 
properties_2017_df = pd.read_csv('/glade/scratch/wmingch/ML_project/Zillow_prize/properties_2017.csv')
# Out:
# <string>:2: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
# <string>:2: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: user 14.2 s, sys: 2.01 s, total: 16.2 s
# Wall time: 16.4 s

# %%
print('properties_2016_df shape: {}'.format(properties_2016_df.shape))
print('properties_2017_df shape: {}'.format(properties_2017_df.shape))
# Out:
# properties_2016_df shape: (2985217, 58)
# properties_2017_df shape: (2985217, 58)

# %%
properties_2016_df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# 0                NaN         NaN                       NaN
# 1                NaN         NaN                       NaN
# 2                NaN         NaN                       NaN
# 3                NaN         NaN                       NaN
# 4                NaN         NaN                       NaN
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  finishedsquarefeet13  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                   NaN
# 2                       73026.0                   NaN                   NaN
# 3                        5068.0                   NaN                   NaN
# 4                        1776.0                   NaN                   NaN
#
#    finishedsquarefeet15  finishedsquarefeet50  finishedsquarefeet6    fips  \
# 0                   NaN                   NaN                  NaN  6037.0
# 1                   NaN                   NaN                  NaN  6037.0
# 2               73026.0                   NaN                  NaN  6037.0
# 3                5068.0                   NaN                  NaN  6037.0
# 4                1776.0                   NaN                  NaN  6037.0
#
#    fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft hashottuborspa  \
# 0           NaN          NaN           NaN              NaN            NaN
# 1           NaN          NaN           NaN              NaN            NaN
# 2           NaN          NaN           NaN              NaN            NaN
# 3           NaN          NaN           NaN              NaN            NaN
# 4           NaN          NaN           NaN              NaN            NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  34144442.0 -118654084.0            85768.0      NaN
# 1                    NaN  34140430.0 -118625364.0             4083.0      NaN
# 2                    NaN  33989359.0 -118394633.0            63085.0      NaN
# 3                    NaN  34148863.0 -118437206.0             7521.0      NaN
# 4                    NaN  34194168.0 -118385816.0             8512.0      NaN
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          NaN
# 3          NaN           NaN          NaN          NaN
# 4          NaN           NaN          NaN          NaN
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                      010D                  269.0                NaN
# 1                      0109                  261.0             LCA11*
# 2                      1200                   47.0               LAC2
# 3                      1200                   47.0               LAC2
# 4                      1210                   31.0               LAM1
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.037800e+07       37688.0          3101.0                   NaN
# 1            6.037800e+07       37688.0          3101.0                   NaN
# 2            6.037703e+07       51617.0          3101.0                   NaN
# 3            6.037141e+07       12447.0          3101.0               27080.0
# 4            6.037123e+07       12447.0          3101.0               46795.0
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      96337.0      0.0          NaN                  NaN
# 1      96337.0      0.0          NaN                  NaN
# 2      96095.0      0.0          NaN                  NaN
# 3      96424.0      0.0          NaN                  NaN
# 4      96450.0      0.0          NaN                  NaN
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN                 NaN                 NaN
# 1                     NaN      NaN                 NaN                 NaN
# 2                     NaN      2.0                 NaN                 NaN
# 3                     NaN      NaN                 NaN                 NaN
# 4                     NaN      1.0                 NaN                 NaN
#
#    yearbuilt  numberofstories fireplaceflag  structuretaxvaluedollarcnt  \
# 0        NaN              NaN           NaN                         NaN
# 1        NaN              NaN           NaN                         NaN
# 2        NaN              NaN           NaN                    650756.0
# 3     1948.0              1.0           NaN                    571346.0
# 4     1947.0              NaN           NaN                    193796.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0                9.0          2015.0                    9.0        NaN
# 1            27516.0          2015.0                27516.0        NaN
# 2          1413387.0          2015.0               762631.0   20800.37
# 3          1156834.0          2015.0               585488.0   14557.57
# 4           433491.0          2015.0               239695.0    5725.17
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                NaN                 NaN                  NaN
# 1                NaN                 NaN                  NaN
# 2                NaN                 NaN                  NaN
# 3                NaN                 NaN                  NaN
# 4                NaN                 NaN                  NaN

# %%
#rename features to make it understandable and convert true/y to 1 
properties_2016_df = data_process(properties_2016_df)
properties_2017_df = data_process(properties_2017_df)

# %%
properties_2017_df.head()
# Out:
#    parcelid  cooling_id  architecture_style_id  basement_sqft  bathroom_cnt  \
# 0  10754147         NaN                    NaN            NaN           0.0
# 1  10759547         NaN                    NaN            NaN           0.0
# 2  10843547         NaN                    NaN            NaN           0.0
# 3  10859147         NaN                    NaN            NaN           0.0
# 4  10879947         NaN                    NaN            NaN           0.0
#
#    bedroom_cnt  framing_id  quality_id  bathroom_cnt_calc  deck_id  \
# 0          0.0         NaN         NaN                NaN      NaN
# 1          0.0         NaN         NaN                NaN      NaN
# 2          0.0         5.0         NaN                NaN      NaN
# 3          0.0         3.0         6.0                NaN      NaN
# 4          0.0         4.0         NaN                NaN      NaN
#
#    floor1_sqft  finished_area_sqft_calc  finished_area_sqft  perimeter_area  \
# 0          NaN                      NaN                 NaN             NaN
# 1          NaN                      NaN                 NaN             NaN
# 2          NaN                  73026.0                 NaN             NaN
# 3          NaN                   5068.0                 NaN             NaN
# 4          NaN                   1776.0                 NaN             NaN
#
#    total_area  floor1_sqft_unk  base_total_area    fips  fireplace_cnt  \
# 0         NaN              NaN              NaN  6037.0            NaN
# 1         NaN              NaN              NaN  6037.0            NaN
# 2     73026.0              NaN              NaN  6037.0            NaN
# 3      5068.0              NaN              NaN  6037.0            NaN
# 4      1776.0              NaN              NaN  6037.0            NaN
#
#    bathroom_full_cnt  garage_cnt  garage_sqft  spa_flag  heating_id  \
# 0                NaN         NaN          NaN       NaN         NaN
# 1                NaN         NaN          NaN       NaN         NaN
# 2                NaN         NaN          NaN       NaN         NaN
# 3                NaN         NaN          NaN       NaN         NaN
# 4                NaN         NaN          NaN       NaN         NaN
#
#      latitude    longitude  lot_sqft  pool_cnt  pool_total_size  pool_unk_1  \
# 0  34144442.0 -118654084.0   85768.0       NaN              NaN         NaN
# 1  34140430.0 -118625364.0    4083.0       NaN              NaN         NaN
# 2  33989359.0 -118394633.0   63085.0       NaN              NaN         NaN
# 3  34148863.0 -118437206.0    7521.0       NaN              NaN         NaN
# 4  34194168.0 -118385816.0    8512.0       NaN              NaN         NaN
#
#    pool_unk_2  pool_unk_3 county_landuse_code  landuse_type_id  \
# 0         NaN         NaN                010D            269.0
# 1         NaN         NaN                0109            261.0
# 2         NaN         NaN                1200             47.0
# 3         NaN         NaN                1200             47.0
# 4         NaN         NaN                1210             31.0
#
#   zoning_description      census_1  city_id  county_id  neighborhood_id  \
# 0                NaN  6.037800e+07  37688.0     3101.0              NaN
# 1             LCA11*  6.037800e+07  37688.0     3101.0              NaN
# 2               LAC2  6.037703e+07  51617.0     3101.0              NaN
# 3               LAC2  6.037141e+07  12447.0     3101.0          27080.0
# 4               LAM1  6.037123e+07  12447.0     3101.0          46795.0
#
#    region_zip  room_cnt  story_id  bathroom_small_cnt  construction_id  \
# 0     96337.0       0.0       NaN                 NaN              NaN
# 1     96337.0       0.0       NaN                 NaN              NaN
# 2     96095.0       0.0       NaN                 NaN              NaN
# 3     96424.0       0.0       NaN                 NaN              NaN
# 4     96450.0       0.0       NaN                 NaN              NaN
#
#    unit_cnt  patio_sqft  storage_sqft  year_built  story_cnt  fireplace_flag  \
# 0       NaN         NaN           NaN         NaN        NaN             NaN
# 1       NaN         NaN           NaN         NaN        NaN             NaN
# 2       2.0         NaN           NaN      1959.0        1.0             NaN
# 3       NaN         NaN           NaN      1948.0        1.0             NaN
# 4       1.0         NaN           NaN      1947.0        1.0             NaN
#
#    tax_structure  tax_parcel  tax_year  tax_land  tax_property  \
# 0            NaN         9.0    2016.0       9.0           NaN
# 1            NaN     27516.0    2015.0   27516.0           NaN
# 2       660680.0   1434941.0    2016.0  774261.0      20800.37
# 3       580059.0   1174475.0    2016.0  594416.0      14557.57
# 4       196751.0    440101.0    2016.0  243350.0       5725.17
#
#    tax_overdue_flag  tax_overdue_year  census_2
# 0               NaN               NaN       NaN
# 1               NaN               NaN       NaN
# 2               NaN               NaN       NaN
# 3               NaN               NaN       NaN
# 4               NaN               NaN       NaN

# %%
for c in properties_2016_df.columns:
    if c not in ['parcelid']:
        print(c)
        print(properties_2016_df[c].value_counts())
# Out:
# cooling_id
# 1.0     742364
# 13.0     58457
# 5.0       8795
# 11.0      1818
# 12.0        59
# 9.0         19
# 3.0          7
# Name: cooling_id, dtype: int64
# architecture_style_id
# 7.0     5251
# 8.0      380
# 2.0      201
# 21.0     150
# 3.0       58
# 5.0       19
# 27.0       1
# 10.0       1
# Name: architecture_style_id, dtype: int64
# basement_sqft
# 1528.0    25
# 700.0     21
# 240.0     21
# 100.0     18
# 144.0     16
#           ..
# 1434.0     1
# 1443.0     1
# 1448.0     1
# 1453.0     1
# 1391.0     1
# Name: basement_sqft, Length: 751, dtype: int64
# bathroom_cnt
# 2.00     1218664
# 3.00      629351
# 1.00      499330
# 2.50      206856
# 4.00      132076
# 0.00      116614
# 1.50       45885
# 5.00       38241
# 3.50       30755
# 4.50       19017
# 6.00       16252
# 7.00        6149
# 5.50        5747
# 8.00        4537
# 9.00        1329
# 6.50        1217
# 10.00        500
# 7.50         380
# 12.00        265
# 11.00        207
# 8.50         106
# 13.00         52
# 9.50          50
# 14.00         45
# 16.00         30
# 15.00         24
# 0.50          17
# 18.00         15
# 10.50         12
# 20.00         10
# 17.00          7
# 1.75           5
# 11.50          3
# 19.00          3
# 12.50          2
# 14.50          1
# 19.50          1
# Name: bathroom_cnt, dtype: int64
# bedroom_cnt
# 3.0     1169462
# 4.0      727052
# 2.0      605367
# 5.0      181222
# 0.0      121466
# 1.0       86610
# 6.0       48563
# 8.0       13555
# 7.0       12744
# 9.0        4293
# 10.0       1726
# 12.0        981
# 11.0        439
# 13.0         89
# 14.0         73
# 16.0         65
# 15.0         26
# 20.0         13
# 18.0         10
# 17.0          8
# 19.0          3
# Name: bedroom_cnt, dtype: int64
# framing_id
# 4.0    9265
# 3.0    3161
# 2.0      81
# 1.0      65
# 5.0      57
# Name: framing_id, dtype: int64
# quality_id
# 7.0     1133238
# 4.0      692160
# 1.0       69467
# 10.0      39713
# 12.0       3692
# 6.0          94
# 8.0          51
# 9.0          25
# 5.0          21
# 11.0         19
# 3.0           6
# 2.0           2
# Name: quality_id, dtype: int64
# bathroom_cnt_calc
# 2.0     1218652
# 3.0      629351
# 1.0      499322
# 2.5      206563
# 4.0      132076
# 1.5       45564
# 5.0       38241
# 3.5       30669
# 4.5       18959
# 6.0       16252
# 7.0        6149
# 5.5        5731
# 8.0        4537
# 9.0        1329
# 6.5        1204
# 10.0        500
# 7.5         377
# 12.0        265
# 11.0        207
# 8.5         102
# 13.0         52
# 9.5          50
# 14.0         45
# 16.0         30
# 15.0         24
# 18.0         15
# 10.5         12
# 20.0         10
# 17.0          7
# 11.5          3
# 19.0          3
# 12.5          2
# 14.5          1
# 19.5          1
# Name: bathroom_cnt_calc, dtype: int64
# deck_id
# 66.0    17096
# Name: deck_id, dtype: int64
# floor1_sqft
# 1252.0    923
# 1233.0    864
# 1120.0    705
# 1226.0    616
# 1612.0    597
#          ...
# 4773.0      1
# 4774.0      1
# 4776.0      1
# 4777.0      1
# 3941.0      1
# Name: floor1_sqft, Length: 4604, dtype: int64
# finished_area_sqft_calc
# 1440.0     8946
# 1344.0     7203
# 1200.0     7098
# 960.0      6014
# 1120.0     5918
#            ...
# 12402.0       1
# 12404.0       1
# 12406.0       1
# 12410.0       1
# 12214.0       1
# Name: finished_area_sqft_calc, Length: 12587, dtype: int64
# finished_area_sqft
# 1440.0     6941
# 1200.0     6636
# 1344.0     6235
# 1120.0     5660
# 960.0      5611
#            ...
# 10523.0       1
# 10525.0       1
# 8329.0        1
# 10530.0       1
# 10307.0       1
# Name: finished_area_sqft, Length: 10670, dtype: int64
# perimeter_area
# 1440.0    1571
# 1344.0     709
# 1248.0     453
# 1536.0     355
# 720.0      245
#           ...
# 810.0        1
# 1690.0       1
# 816.0        1
# 820.0        1
# 1922.0       1
# Name: perimeter_area, Length: 250, dtype: int64
# total_area
# 1536.0    647
# 1728.0    429
# 1600.0    415
# 1440.0    413
# 1800.0    402
#          ...
# 8913.0      1
# 8915.0      1
# 8935.0      1
# 8944.0      1
# 512.0       1
# Name: total_area, Length: 8816, dtype: int64
# floor1_sqft_unk
# 1252.0    923
# 1233.0    864
# 1120.0    705
# 1226.0    616
# 1612.0    597
#          ...
# 3551.0      1
# 4874.0      1
# 4872.0      1
# 4868.0      1
# 4065.0      1
# Name: floor1_sqft_unk, Length: 4802, dtype: int64
# base_total_area
# 952.0     101
# 800.0      90
# 3820.0     88
# 720.0      74
# 600.0      68
#          ...
# 3675.0      1
# 3676.0      1
# 3683.0      1
# 1414.0      1
# 2722.0      1
# Name: base_total_area, Length: 4251, dtype: int64
# fips
# 6037.0    2009362
# 6059.0     741565
# 6111.0     222853
# Name: fips, dtype: int64
# fireplace_cnt
# 1.0    269643
# 2.0     34407
# 3.0      7696
# 4.0       710
# 5.0       126
# 6.0        32
# 7.0        15
# 9.0         6
# 8.0         2
# Name: fireplace_cnt, dtype: int64
# bathroom_full_cnt
# 2.0     1425661
# 3.0      660139
# 1.0      544928
# 4.0      151004
# 5.0       43918
# 6.0       17198
# 7.0        6409
# 8.0        4557
# 9.0        1339
# 10.0        498
# 12.0        263
# 11.0        204
# 13.0         53
# 14.0         45
# 16.0         30
# 15.0         23
# 18.0         15
# 20.0         10
# 17.0          7
# 19.0          4
# Name: bathroom_full_cnt, dtype: int64
# garage_cnt
# 2.0     660462
# 1.0     177579
# 3.0      19634
# 0.0      14005
# 4.0       8495
# 5.0       1705
# 6.0        575
# 7.0        266
# 8.0        181
# 9.0        127
# 10.0        78
# 11.0        62
# 12.0        41
# 13.0        16
# 14.0        14
# 15.0         9
# 17.0         4
# 16.0         3
# 19.0         3
# 21.0         2
# 20.0         2
# 24.0         2
# 25.0         1
# 18.0         1
# Name: garage_cnt, dtype: int64
# garage_sqft
# 0.0       196752
# 400.0      33443
# 360.0      29703
# 441.0      26753
# 462.0      25476
#            ...
# 2226.0         1
# 2230.0         1
# 2231.0         1
# 2233.0         1
# 2221.0         1
# Name: garage_sqft, Length: 2240, dtype: int64
# spa_flag
# 1.0    69014
# Name: spa_flag, dtype: int64
# heating_id
# 2.0     1156830
# 7.0      595453
# 6.0       27480
# 24.0      21107
# 20.0       3216
# 13.0       1342
# 18.0        586
# 1.0         262
# 14.0         41
# 10.0         39
# 12.0         25
# 11.0         16
# 21.0          3
# 19.0          1
# Name: heating_id, dtype: int64
# latitude
# 33984600.0    862
# 33708500.0    760
# 34056700.0    740
# 34171800.0    611
# 33766300.0    568
#              ...
# 34580638.0      1
# 34548742.0      1
# 33952735.0      1
# 33737780.0      1
# 33494518.0      1
# Name: latitude, Length: 852325, dtype: int64
# longitude
# -118390000.0    1718
# -118438000.0    1585
# -118389000.0    1568
# -118252000.0    1402
# -118432000.0    1371
#                 ...
# -117799630.0       1
# -118234190.0       1
# -118509887.0       1
# -118754556.0       1
# -117953201.0       1
# Name: longitude, Length: 1042550, dtype: int64
# lot_sqft
# 6000.0      44730
# 5000.0      17546
# 7200.0      15383
# 7000.0      11956
# 6500.0      11624
#             ...
# 57755.0         1
# 57753.0         1
# 57752.0         1
# 57749.0         1
# 131039.0        1
# Name: lot_sqft, Length: 69953, dtype: int64
# pool_cnt
# 1.0    517534
# Name: pool_cnt, dtype: int64
# pool_total_size
# 450.0     3179
# 400.0      972
# 480.0      917
# 500.0      828
# 512.0      826
#           ...
# 1090.0       1
# 1094.0       1
# 1116.0       1
# 1121.0       1
# 1142.0       1
# Name: pool_total_size, Length: 907, dtype: int64
# pool_unk_1
# 1.0    36939
# Name: pool_unk_1, dtype: int64
# pool_unk_2
# 1.0    32075
# Name: pool_unk_2, dtype: int64
# pool_unk_3
# 1.0    485459
# Name: pool_unk_3, dtype: int64
# county_landuse_code
# 0100    1153896
# 122      522145
# 0101     247494
# 010C     225410
# 1111     126491
#          ...
# 070V          1
# 3414          1
# 76            1
# 03TO          1
# 0305          1
# Name: county_landuse_code, Length: 240, dtype: int64
# landuse_type_id
# 261.0    2148362
# 266.0     481067
# 246.0     114888
# 269.0      61469
# 263.0      58438
# 248.0      40325
# 247.0      40022
# 31.0        9462
# 265.0       9421
# 47.0        4314
# 260.0       2754
# 267.0       1817
# 275.0       1201
# 264.0        204
# 270.0         36
# Name: landuse_type_id, dtype: int64
# zoning_description
# LAR1      275029
# LAR3       67105
# LARS       54859
# LBR1N      52750
# LAR2       48808
#            ...
# RBR2X          1
# GANESP         1
# RAR1*          1
# BUC3           1
# CVR1           1
# Name: zoning_description, Length: 5638, dtype: int64
# census_1
# 6.059052e+07    1518
# 6.037920e+07    1455
# 6.059063e+07     895
# 6.037137e+07     886
# 6.037577e+07     825
#                 ...
# 6.037900e+07       1
# 6.111004e+07       1
# 6.037911e+07       1
# 6.037311e+07       1
# 6.059063e+07       1
# Name: census_1, Length: 99393, dtype: int64
# city_id
# 12447.0    670925
# 46298.0     93470
# 16764.0     59802
# 52650.0     58234
# 25218.0     56962
#             ...
# 27512.0        12
# 36078.0        12
# 47913.0         7
# 3980.0          6
# 40633.0         5
# Name: city_id, Length: 186, dtype: int64
# county_id
# 3101.0    2009362
# 1286.0     741565
# 2061.0     222853
# Name: county_id, dtype: int64
# neighborhood_id
# 118208.0    32267
# 268496.0    23186
# 48570.0     21186
# 27080.0     18891
# 37739.0     18645
#             ...
# 275316.0        4
# 275287.0        3
# 275855.0        3
# 764092.0        3
# 273552.0        1
# Name: neighborhood_id, Length: 528, dtype: int64
# region_zip
# 96987.0    22021
# 96193.0    21759
# 97118.0    20612
# 97319.0    20310
# 96964.0    19898
#            ...
# 96453.0        1
# 96068.0        1
# 97096.0        1
# 96953.0        1
# 96258.0        1
# Name: region_zip, Length: 405, dtype: int64
# room_cnt
# 0.0     2308879
# 6.0      178357
# 7.0      156397
# 8.0      120227
# 5.0       99582
# 9.0       45241
# 4.0       42320
# 10.0      10862
# 3.0        6289
# 11.0       3021
# 12.0       1097
# 2.0         751
# 13.0        313
# 14.0        156
# 1.0          77
# 15.0         67
# 16.0         35
# 18.0         22
# 30.0         14
# 17.0          9
# 19.0          6
# 21.0          4
# 20.0          3
# 22.0          1
# 24.0          1
# 96.0          1
# 40.0          1
# 42.0          1
# 45.0          1
# 52.0          1
# 56.0          1
# 67.0          1
# 77.0          1
# 84.0          1
# 86.0          1
# 31.0          1
# Name: room_cnt, dtype: int64
# story_id
# 7.0    1624
# Name: story_id, dtype: int64
# bathroom_small_cnt
# 1.0    308959
# 2.0      2338
# 3.0       261
# 4.0        46
# 5.0        16
# 6.0         9
# 7.0         2
# Name: bathroom_small_cnt, dtype: int64
# construction_id
# 6.0     6670
# 4.0       59
# 13.0      14
# 10.0       3
# 11.0       1
# Name: construction_id, dtype: int64
# unit_cnt
# 1.0      1780051
# 2.0       115652
# 4.0        39877
# 3.0        39830
# 5.0          588
#           ...
# 113.0          1
# 53.0           1
# 112.0          1
# 55.0           1
# 502.0          1
# Name: unit_cnt, Length: 146, dtype: int64
# patio_sqft
# 240.0     3190
# 200.0     2980
# 300.0     2272
# 180.0     1492
# 288.0     1443
#           ...
# 1277.0       1
# 1274.0       1
# 1267.0       1
# 1266.0       1
# 1415.0       1
# Name: patio_sqft, Length: 1636, dtype: int64
# storage_sqft
# 120.0    91
# 100.0    69
# 240.0    61
# 160.0    55
# 80.0     53
#          ..
# 79.0      1
# 83.0      1
# 86.0      1
# 89.0      1
# 512.0     1
# Name: storage_sqft, Length: 594, dtype: int64
# year_built
# 1955.0    88586
# 1950.0    76142
# 1954.0    73307
# 1953.0    67085
# 1956.0    65736
#           ...
# 1829.0        1
# 1831.0        1
# 1833.0        1
# 1834.0        1
# 1827.0        1
# Name: year_built, Length: 168, dtype: int64
# story_cnt
# 1.0     424186
# 2.0     242125
# 3.0      15678
# 4.0         58
# 5.0         11
# 6.0          4
# 7.0          2
# 41.0         1
# 20.0         1
# 17.0         1
# 14.0         1
# 8.0          1
# Name: story_cnt, dtype: int64
# fireplace_flag
# 1.0    5163
# Name: fireplace_flag, dtype: int64
# tax_structure
# 100000.0    1880
# 102461.0    1578
# 104510.0    1513
# 200000.0    1418
# 107401.0    1411
#             ...
# 828736.0       1
# 828766.0       1
# 351070.0       1
# 351069.0       1
# 433093.0       1
# Name: tax_structure, Length: 426150, dtype: int64
# tax_parcel
# 9.0          1889
# 400000.0     1572
# 350000.0     1511
# 450000.0     1459
# 500000.0     1339
#              ...
# 1080575.0       1
# 1080573.0       1
# 456817.0        1
# 456818.0        1
# 374793.0        1
# Name: tax_parcel, Length: 638920, dtype: int64
# tax_year
# 2015.0    2972420
# 2014.0       1306
# 2012.0         26
# 2004.0          6
# 2013.0          4
# 2003.0          3
# 2001.0          3
# 2010.0          2
# 2009.0          2
# 2005.0          2
# 2016.0          1
# 2011.0          1
# 2002.0          1
# 2000.0          1
# Name: tax_year, dtype: int64
# tax_land
# 20980.0     3804
# 22414.0     2474
# 16275.0     2377
# 19149.0     2218
# 9.0         2172
#             ...
# 975757.0       1
# 409873.0       1
# 409877.0       1
# 409878.0       1
# 341636.0       1
# Name: tax_land, Length: 531408, dtype: int64
# tax_property
# 345.72      171
# 1844.16     124
# 1045.88     110
# 5.02        103
# 1481.24     102
#            ...
# 11298.46      1
# 6476.27       1
# 11610.84      1
# 12959.11      1
# 152.78        1
# Name: tax_property, Length: 1045757, dtype: int64
# tax_overdue_flag
# 1.0    56462
# Name: tax_overdue_flag, dtype: int64
# tax_overdue_year
# 15.0    26068
# 14.0    16826
# 13.0     4632
# 12.0     3124
# 11.0     2350
# 10.0     1552
# 9.0      1016
# 8.0       501
# 7.0       236
# 6.0        71
# 5.0        23
# 4.0        16
# 92.0        5
# 95.0        5
# 3.0         5
# 99.0        4
# 2.0         4
# 93.0        3
# 98.0        3
# 0.0         2
# 1.0         2
# 90.0        2
# 91.0        2
# 94.0        2
# 97.0        2
# 79.0        2
# 82.0        1
# 84.0        1
# 86.0        1
# 87.0        1
# 88.0        1
# 96.0        1
# Name: tax_overdue_year, dtype: int64
# census_2
# 6.037920e+13    1171
# 6.037137e+13     881
# 6.037920e+13     811
# 6.059063e+13     807
# 6.059052e+13     806
#                 ...
# 6.059063e+13       1
# 6.037113e+13       1
# 6.111008e+13       1
# 6.037800e+13       1
# 6.111000e+13       1
# Name: census_2, Length: 96771, dtype: int64

# %%
#land use code 

def get_landuse_code_df(properties_2016_df, properties_2017_df):
    temp = properties_2016_df.groupby('county_landuse_code')['county_landuse_code'].count()
    landuse_codes = list(temp[temp >= 300].index)
    temp = properties_2017_df.groupby('county_landuse_code')['county_landuse_code'].count()
    landuse_codes += list(temp[temp >= 300].index) 
    landuse_codes = list(set(landuse_codes))
    
    df_landuse_codes = pd.DataFrame({'county_landuse_code': landuse_codes, 'county_landuse_code_id': range(len(landuse_codes))})
    return df_landuse_codes

df_landuse_codes = get_landuse_code_df(properties_2016_df, properties_2017_df)

# %%
#zoning des use code 

def get_zoning_desc_code_df(properties_2016_df, properties_2017_df):
    temp = properties_2016_df.groupby('zoning_description')['zoning_description'].count().sort_values(ascending=False)
    zoning_codes = list(temp[temp > 300].index)
    temp = properties_2017_df.groupby('zoning_description')['zoning_description'].count().sort_values(ascending=False)
    zoning_codes += list(temp[temp > 300].index)
    zoning_codes = list(set(zoning_codes))
    
    df_zoning_codes = pd.DataFrame({'zoning_description': zoning_codes, 'zoning_description_id':range(len(zoning_codes))})

    return df_zoning_codes

df_zoning_codes = get_zoning_desc_code_df(properties_2016_df, properties_2017_df)

# %%
#merge land use and zoning codes 
#for count smaller than 300 will be NaN
properties_2016_df = properties_2016_df.merge(how='left', right=df_landuse_codes, on='county_landuse_code', copy=False)
properties_2016_df = properties_2016_df.merge(how='left', right=df_zoning_codes, on='zoning_description', copy=False)
properties_2016_df = properties_2016_df.drop(['county_landuse_code','zoning_description'],axis=1)

# %%
properties_2017_df = properties_2017_df.merge(how='left', right=df_landuse_codes, on='county_landuse_code', copy=False)
properties_2017_df = properties_2017_df.merge(how='left', right=df_zoning_codes, on='zoning_description', copy=False)
properties_2017_df = properties_2017_df.drop(['county_landuse_code','zoning_description'],axis=1)

# %%
#county_id, convert to 0, 1, and 2
properties_2016_df.loc[properties_2016_df.county_id == 3101, 'county_id'] = 0
properties_2016_df.loc[properties_2016_df.county_id == 1286, 'county_id'] = 1
properties_2016_df.loc[properties_2016_df.county_id == 2061, 'county_id'] = 2

properties_2017_df.loc[properties_2017_df.county_id == 3101, 'county_id'] = 0
properties_2017_df.loc[properties_2017_df.county_id == 1286, 'county_id'] = 1
properties_2017_df.loc[properties_2017_df.county_id == 2061, 'county_id'] = 2

# %% [markdown]
# ## Some feature engineering

# %%
for prop in [properties_2016_df, properties_2017_df]:
    prop['avg_garage_size'] = prop['garage_sqft']/prop['garage_cnt']
    prop['property_tax_per_sqft'] = prop['tax_property'] / prop['finished_area_sqft_calc']
    prop['location_1'] = prop['latitude'] + prop['longitude']
    prop['location_2'] = prop['latitude'] - prop['longitude']
    prop['location_3'] = prop['latitude'] + 0.5 * prop['longitude']
    prop['location_4'] = prop['latitude'] - 0.5 * prop['longitude']
    
    prop['missing_finished_area'] = prop['finished_area_sqft'].isnull().astype(np.float32)
    prop['missing_total_area'] = prop['total_area'].isnull().astype(np.float32)
    prop.drop(['finished_area_sqft', 'total_area'], axis=1, inplace=True)
    
    prop['missing_bathroom_cnt_calc'] = prop['bathroom_cnt_calc'].isnull().astype(np.float32)
    prop.drop(['bathroom_cnt_calc'], axis=1, inplace=True)
    
    prop['derived_room_cnt'] = prop['bedroom_cnt'] + prop['bathroom_cnt']
    mask = (prop.room_cnt >= 1)
    prop.loc[mask, 'avg_area_per_room'] = prop.loc[mask, 'finished_area_sqft_calc']/prop.loc[mask, 'room_cnt']
    
    mask = (prop.derived_room_cnt >= 1)
    prop.loc[mask, 'derived_avg_area_per_room'] = prop.loc[mask, 'finished_area_sqft_calc']/prop.loc[mask, 'derived_room_cnt']

# %%
properties_2016_df.head()
# Out:
#    parcelid  cooling_id  architecture_style_id  basement_sqft  bathroom_cnt  \
# 0  10754147         NaN                    NaN            NaN           0.0
# 1  10759547         NaN                    NaN            NaN           0.0
# 2  10843547         NaN                    NaN            NaN           0.0
# 3  10859147         NaN                    NaN            NaN           0.0
# 4  10879947         NaN                    NaN            NaN           0.0
#
#    bedroom_cnt  framing_id  quality_id  deck_id  floor1_sqft  \
# 0          0.0         NaN         NaN      NaN          NaN
# 1          0.0         NaN         NaN      NaN          NaN
# 2          0.0         NaN         NaN      NaN          NaN
# 3          0.0         3.0         7.0      NaN          NaN
# 4          0.0         4.0         NaN      NaN          NaN
#
#    finished_area_sqft_calc  perimeter_area  floor1_sqft_unk  base_total_area  \
# 0                      NaN             NaN              NaN              NaN
# 1                      NaN             NaN              NaN              NaN
# 2                  73026.0             NaN              NaN              NaN
# 3                   5068.0             NaN              NaN              NaN
# 4                   1776.0             NaN              NaN              NaN
#
#      fips  fireplace_cnt  bathroom_full_cnt  garage_cnt  garage_sqft  \
# 0  6037.0            NaN                NaN         NaN          NaN
# 1  6037.0            NaN                NaN         NaN          NaN
# 2  6037.0            NaN                NaN         NaN          NaN
# 3  6037.0            NaN                NaN         NaN          NaN
# 4  6037.0            NaN                NaN         NaN          NaN
#
#    spa_flag  heating_id    latitude    longitude  lot_sqft  pool_cnt  \
# 0       NaN         NaN  34144442.0 -118654084.0   85768.0       NaN
# 1       NaN         NaN  34140430.0 -118625364.0    4083.0       NaN
# 2       NaN         NaN  33989359.0 -118394633.0   63085.0       NaN
# 3       NaN         NaN  34148863.0 -118437206.0    7521.0       NaN
# 4       NaN         NaN  34194168.0 -118385816.0    8512.0       NaN
#
#    pool_total_size  pool_unk_1  pool_unk_2  pool_unk_3  landuse_type_id  \
# 0              NaN         NaN         NaN         NaN            269.0
# 1              NaN         NaN         NaN         NaN            261.0
# 2              NaN         NaN         NaN         NaN             47.0
# 3              NaN         NaN         NaN         NaN             47.0
# 4              NaN         NaN         NaN         NaN             31.0
#
#        census_1  city_id  county_id  neighborhood_id  region_zip  room_cnt  \
# 0  6.037800e+07  37688.0        0.0              NaN     96337.0       0.0
# 1  6.037800e+07  37688.0        0.0              NaN     96337.0       0.0
# 2  6.037703e+07  51617.0        0.0              NaN     96095.0       0.0
# 3  6.037141e+07  12447.0        0.0          27080.0     96424.0       0.0
# 4  6.037123e+07  12447.0        0.0          46795.0     96450.0       0.0
#
#    story_id  bathroom_small_cnt  construction_id  unit_cnt  patio_sqft  \
# 0       NaN                 NaN              NaN       NaN         NaN
# 1       NaN                 NaN              NaN       NaN         NaN
# 2       NaN                 NaN              NaN       2.0         NaN
# 3       NaN                 NaN              NaN       NaN         NaN
# 4       NaN                 NaN              NaN       1.0         NaN
#
#    storage_sqft  year_built  story_cnt  fireplace_flag  tax_structure  \
# 0           NaN         NaN        NaN             NaN            NaN
# 1           NaN         NaN        NaN             NaN            NaN
# 2           NaN         NaN        NaN             NaN       650756.0
# 3           NaN      1948.0        1.0             NaN       571346.0
# 4           NaN      1947.0        NaN             NaN       193796.0
#
#    tax_parcel  tax_year  tax_land  tax_property  tax_overdue_flag  \
# 0         9.0    2015.0       9.0           NaN               NaN
# 1     27516.0    2015.0   27516.0           NaN               NaN
# 2   1413387.0    2015.0  762631.0      20800.37               NaN
# 3   1156834.0    2015.0  585488.0      14557.57               NaN
# 4    433491.0    2015.0  239695.0       5725.17               NaN
#
#    tax_overdue_year  census_2  county_landuse_code_id  zoning_description_id  \
# 0               NaN       NaN                    43.0                    NaN
# 1               NaN       NaN                    28.0                  279.0
# 2               NaN       NaN                    25.0                  411.0
# 3               NaN       NaN                    25.0                  411.0
# 4               NaN       NaN                    48.0                  194.0
#
#    avg_garage_size  property_tax_per_sqft  location_1   location_2  \
# 0              NaN                    NaN -84509642.0  152798526.0
# 1              NaN                    NaN -84484934.0  152765794.0
# 2              NaN               0.284835 -84405274.0  152383992.0
# 3              NaN               2.872449 -84288343.0  152586069.0
# 4              NaN               3.223632 -84191648.0  152579984.0
#
#    location_3  location_4  missing_finished_area  missing_total_area  \
# 0 -25182600.0  93471484.0                    1.0                 1.0
# 1 -25172252.0  93453112.0                    1.0                 1.0
# 2 -25207957.5  93186675.5                    1.0                 0.0
# 3 -25069740.0  93367466.0                    1.0                 0.0
# 4 -24998740.0  93387076.0                    1.0                 0.0
#
#    missing_bathroom_cnt_calc  derived_room_cnt  avg_area_per_room  \
# 0                        1.0               0.0                NaN
# 1                        1.0               0.0                NaN
# 2                        1.0               0.0                NaN
# 3                        1.0               0.0                NaN
# 4                        1.0               0.0                NaN
#
#    derived_avg_area_per_room
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
# save properties to hdf files for predictions
dir_temp = '/glade/scratch/wmingch/ML_project/Zillow_prize/temp_data/'
properties_2016_df.to_hdf(dir_temp + 'properties_2016.h5', key='properties_2016_df', mode='w')
properties_2017_df.to_hdf(dir_temp + 'properties_2017.h5', key='properties_2017_df', mode='a')

# %% [markdown]
# ## train_2016 and train_2017 for model training

# %%
def add_simple_datetime_features(df):
    dt = pd.to_datetime(df.transactiondate).dt
    df['year'] = (dt.year - 2016).astype(int)
    df['month'] = (dt.month).astype(int)
    df['quarter'] = (dt.quarter).astype(int)
    df.drop(['transactiondate'], axis=1, inplace=True)

# %%
# %%time
target_2016_df = pd.read_csv('/glade/scratch/wmingch/ML_project/Zillow_prize/train_2016_v2.csv',parse_dates=["transactiondate"])
target_2017_df = pd.read_csv('/glade/scratch/wmingch/ML_project/Zillow_prize/train_2017.csv',parse_dates=["transactiondate"])

train_2016_df = target_2016_df.merge(how='left', right=properties_2016_df, on='parcelid')
train_2017_df = target_2017_df.merge(how='left', right=properties_2017_df, on='parcelid')
# Out:
# CPU times: user 2.64 s, sys: 1.14 s, total: 3.79 s
# Wall time: 3.87 s

# %%
# add datetime features 
add_simple_datetime_features(train_2016_df)
add_simple_datetime_features(train_2017_df)

# %%
# concat train_2016 and train_2017
train_combined = pd.concat([train_2016_df, train_2017_df], axis=0, ignore_index=True)

# %%
train_combined.head()
# Out:
#    parcelid  logerror  cooling_id  architecture_style_id  basement_sqft  \
# 0  11016594    0.0276         1.0                    NaN            NaN
# 1  14366692   -0.1684         NaN                    NaN            NaN
# 2  12098116   -0.0040         1.0                    NaN            NaN
# 3  12643413    0.0218         1.0                    NaN            NaN
# 4  14432541   -0.0050         NaN                    NaN            NaN
#
#    bathroom_cnt  bedroom_cnt  framing_id  quality_id  deck_id  floor1_sqft  \
# 0           2.0          3.0         NaN         4.0      NaN          NaN
# 1           3.5          4.0         NaN         NaN      NaN          NaN
# 2           3.0          2.0         NaN         4.0      NaN          NaN
# 3           2.0          2.0         NaN         4.0      NaN          NaN
# 4           2.5          4.0         NaN         NaN      NaN          NaN
#
#    finished_area_sqft_calc  perimeter_area  floor1_sqft_unk  base_total_area  \
# 0                   1684.0             NaN              NaN              NaN
# 1                   2263.0             NaN              NaN              NaN
# 2                   2217.0             NaN              NaN              NaN
# 3                    839.0             NaN              NaN              NaN
# 4                   2283.0             NaN              NaN              NaN
#
#      fips  fireplace_cnt  bathroom_full_cnt  garage_cnt  garage_sqft  \
# 0  6037.0            NaN                2.0         NaN          NaN
# 1  6059.0            NaN                3.0         2.0        468.0
# 2  6037.0            NaN                3.0         NaN          NaN
# 3  6037.0            NaN                2.0         NaN          NaN
# 4  6059.0            NaN                2.0         2.0        598.0
#
#    spa_flag  heating_id    latitude    longitude  lot_sqft  pool_cnt  \
# 0       NaN         2.0  34280990.0 -118488536.0    7528.0       NaN
# 1       NaN         NaN  33668120.0 -117677556.0    3643.0       NaN
# 2       NaN         2.0  34136312.0 -118175032.0   11423.0       NaN
# 3       NaN         2.0  33755800.0 -118309000.0   70859.0       NaN
# 4       NaN         NaN  33485643.0 -117700234.0    6000.0       1.0
#
#    pool_total_size  pool_unk_1  pool_unk_2  pool_unk_3  landuse_type_id  \
# 0              NaN         NaN         NaN         NaN            261.0
# 1              NaN         NaN         NaN         NaN            261.0
# 2              NaN         NaN         NaN         NaN            261.0
# 3              NaN         NaN         NaN         NaN            266.0
# 4              NaN         NaN         NaN         1.0            261.0
#
#        census_1  city_id  county_id  neighborhood_id  region_zip  room_cnt  \
# 0  6.037107e+07  12447.0        0.0          31817.0     96370.0       0.0
# 1  6.059052e+07  32380.0        1.0              NaN     96962.0       0.0
# 2  6.037464e+07  47019.0        0.0         275411.0     96293.0       0.0
# 3  6.037296e+07  12447.0        0.0          54300.0     96222.0       0.0
# 4  6.059042e+07  17686.0        1.0              NaN     96961.0       8.0
#
#    story_id  bathroom_small_cnt  construction_id  unit_cnt  patio_sqft  \
# 0       NaN                 NaN              NaN       1.0         NaN
# 1       NaN                 1.0              NaN       NaN         NaN
# 2       NaN                 NaN              NaN       1.0         NaN
# 3       NaN                 NaN              NaN       1.0         NaN
# 4       NaN                 1.0              NaN       NaN         NaN
#
#    storage_sqft  year_built  story_cnt  fireplace_flag  tax_structure  \
# 0           NaN      1959.0        NaN             NaN       122754.0
# 1           NaN      2014.0        NaN             NaN       346458.0
# 2           NaN      1940.0        NaN             NaN        61994.0
# 3           NaN      1987.0        NaN             NaN       171518.0
# 4           NaN      1981.0        2.0             NaN       169574.0
#
#    tax_parcel  tax_year  tax_land  tax_property  tax_overdue_flag  \
# 0    360170.0    2015.0  237416.0       6735.88               NaN
# 1    585529.0    2015.0  239071.0      10153.02               NaN
# 2    119906.0    2015.0   57912.0      11484.48               NaN
# 3    244880.0    2015.0   73362.0       3048.74               NaN
# 4    434551.0    2015.0  264977.0       5488.96               NaN
#
#    tax_overdue_year      census_2  county_landuse_code_id  \
# 0               NaN  6.037107e+13                     3.0
# 1               NaN           NaN                    36.0
# 2               NaN  6.037464e+13                     3.0
# 3               NaN  6.037296e+13                    13.0
# 4               NaN  6.059042e+13                    16.0
#
#    zoning_description_id  avg_garage_size  property_tax_per_sqft  location_1  \
# 0                   79.0              NaN               3.999929 -84207546.0
# 1                    NaN            234.0               4.486531 -84009436.0
# 2                  604.0              NaN               5.180189 -84038720.0
# 3                  626.0              NaN               3.633778 -84553200.0
# 4                    NaN            299.0               2.404275 -84214591.0
#
#     location_2  location_3  location_4  missing_finished_area  \
# 0  152769526.0 -24963278.0  93525258.0                    0.0
# 1  151345676.0 -25170658.0  92506898.0                    0.0
# 2  152311344.0 -24951204.0  93223828.0                    0.0
# 3  152064800.0 -25398700.0  92910300.0                    0.0
# 4  151185877.0 -25364474.0  92335760.0                    0.0
#
#    missing_total_area  missing_bathroom_cnt_calc  derived_room_cnt  \
# 0                 1.0                        0.0               5.0
# 1                 1.0                        0.0               7.5
# 2                 1.0                        0.0               5.0
# 3                 1.0                        0.0               4.0
# 4                 1.0                        0.0               6.5
#
#    avg_area_per_room  derived_avg_area_per_room  year  month  quarter
# 0                NaN                 336.800000     0      1        1
# 1                NaN                 301.733333     0      1        1
# 2                NaN                 443.400000     0      1        1
# 3                NaN                 209.750000     0      1        1
# 4            285.375                 351.230769     0      1        1

# %%
train_combined.to_hdf(dir_temp + 'train_combined.h5', key='train_combined', mode='w')
